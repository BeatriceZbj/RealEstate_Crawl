# %%
# This code reads the text content and identifies the feature names and related values.
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter
import ast



def extract_information(file):
    with open(file, mode="r") as ins:
        data = []
        mls_number = ""

        state = None
        for line in ins:

            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue
            elif line == "SchoolsEducation :\n":
                state = "PH_Skip_Next_Then_Parse_Next_Line"
                continue

            if state == "LS_Parse_Next_Line":
                entries = eval(line)  # Read the line as JSON array.
#                 print(entries)
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]
#                         print(mls_number)
                state = None

#             elif state == "PH_Parse_Next_Line":
#                 data = eval(line)
#                 print(data)
#                 state = None

            elif state == "PH_Skip_Next_Then_Parse_Next_Line":
                data=eval(line)
                print(data)
                state=None
#                 state = "PH_Parse_Next_Line"

        for row in data:
            row.insert(0, mls_number)

        return data
#     print(data)
    
mypath = "C:\\Users\\39118\\Desktop\\Python Program\\LIINFO"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector

headers = ['a', 'b', 'c', 'd', 'e']

rows = []
count = 0
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\Python Program\\LIINFO\\" + file)
    rows = rows+ data
    print(rows)

df = pd.DataFrame.from_records(rows, columns=headers)
# print(df)
# df = pd.DataFrame({'a': headers, 'b': rows})
# df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\NeighborData.xlsx') as writer:
    df.to_excel(writer, 'sheet1',startrow=0, startcol=0, header=True, index=False)
# Out:
# (['College Degree - 2 year', '9.0%', '9.0%', '9.0%', '8.0%', 'The percentage of the area’s population over the age of 25 with an Associate Degree or other 2-year college degree.'], ['College Degree - 4 year', '17.0%', '17.0%', '19.0%', '19.0%', 'The percentage of the area’s population over the age of 25 with a bachelor’s degree or other 4-year college degree.'])
# (['00771912', 'Amityville Memorial High School', '10', '12', 717, 12, '11701', 1, 'Amityville Memorial High School', 'H ', '5'], ['00774122', 'Lindenhurst Senior High School', '09', '12', 2000, 14, '11757', 1, 'Lindenhurst Senior High School', 'H ', '5'], ['00737318', 'Massapequa High School', '10', '12', 1848, 13, '11758', 1, 'Massapequa High School', 'H ', '5'], ['00772992', 'Walter G O Connell Copiague High School', '09', '12', 1610, 14, '11726', 1, 'Walter G O Connell Copiague High School', 'H ', '5'], ['00737978', 'Plainedge Senior High School', '09', '12', 984, 13, '11758', 1, 'Plainedge Senior High School', 'H ', '5'])
# (['00771900', 'Edmund W Miles Middle School', '07', '09', 650, 13, '11701', 1, 'Edmund W Miles Middle School', 'M ', '5'], ['00774110', 'Lindenhurst Middle School', '06', '08', 1400, 12, '11757', 1, 'Lindenhurst Middle School', 'M ', '5'], ['00773001', 'Copiague Middle School', '06', '08', 1100, 14, '11726', 1, 'Copiague Middle School', 'M ', '5'], ['00737241', 'Berner Middle School', '07', '08', 1100, 12, '11758', 1, 'Berner Middle School', 'M ', '5'], ['04875429', 'Massapequa High Ames Campus', '09', '09', 545, 10, '11758', 1, 'Massapequa High Ames Campus', 'M ', '5'])
# (['00771948', 'Park Avenue School', '04', '06', 700, 10, '11701', 1, 'Park Avenue School', 'E ', '5'], ['00771924', 'Northwest Elementary School', '01', '03', 650, 11, '11701', 1, 'Northwest Elementary School', 'E ', '5'], ['00773049', 'Susan E Wiley School', 'KG', '05', 900, 16, '11726', 1, 'Susan E Wiley School', 'E ', '5'], ['00737332', 'Unqua Elementary School', 'KG', '05', 670, 12, '11758', 1, 'Unqua Elementary School', 'E ', '5'], ['00737291', 'Mckenna Elementary School', 'KG', '06', 621, 9, '11762', 1, 'Mckenna Elementary School', 'E ', '5'], ['00737253', 'Birch Lane Elementary School', 'KG', '05', 618, 12, '11762', 1, 'Birch Lane Elementary School', 'E ', '5'], ['00735449', 'Albany Avenue Elementary School', 'KG', '05', 565, 11, '11758', 1, 'Albany Avenue Elementary School', 'E ', '5'], ['00774158', 'William Rall School', 'KG', '05', 560, 14, '11757', 1, 'William Rall School', 'E ', '5'], ['00773025', 'Great Neck Road Elementary School', 'KG', '05', 535, 17, '11726', 1, 'Great Neck Road Elementary School', 'E ', '5'], ['00774079', 'Daniel Street School', 'KG', '05', 526, 12, '11757', 1, 'Daniel Street School', 'E ', '5'])
# ['5700050096', 'Northeast School', 'PK', 'KG', 300, 14, '11701', 1, 'Northeast School', 'U ', '5']
# (['01464069', 'Bethesda Sda Elementary School', 'PK', '10', 43, 0, '11701', '1', 'Bethesda Sda Elementary School'], ['00740585', 'St Rose Of Lima Elementary School', 'PK', '08', 484, 17, '11758', '1', 'St Rose Of Lima Elementary School'], ['5700048488', 'St Martin Of Tours School', 'PK', '08', 372, 21, '11701', '1', 'St Martin Of Tours School'], ['02932588', 'Kid Esteem Montessori School', 'PK', '08', 100, 10, '11757', '1', 'Kid Esteem Montessori School'], ['02991572', 'Copiague Christian Academy', 'PK', '02', 44, 6, '11726', '1', 'Copiague Christian Academy'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-71a037d6121b> in <module>
#      58 for file in list_files:
#      59     data = extract_information("C:\\Users\\39118\\Desktop\\Python Program\\LIINFO\\" + file)
# ---> 60     rows = rows+ data
#      61     print(rows)
#      62
#
# TypeError: can only concatenate list (not "tuple") to list

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter
import ast



def extract_information(file):
    with open(file, mode="r") as ins:
        data = []
        mls_number = ""

        state = None
        for line in ins:

            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue
            elif line == "SchoolsEducation :\n":
                state = "PH_Skip_Next_Then_Parse_Next_Line"
                continue

            if state == "LS_Parse_Next_Line":
                entries = eval(line)  # Read the line as JSON array.
#                 print(entries)
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]
#                         print(mls_number)
                state = None

            elif state == "PH_Parse_Next_Line":
                data = eval(line)
                print(data)
                state = None

            elif state == "PH_Skip_Next_Then_Parse_Next_Line":
                data=eval(line)
#                 print(data)
                state=None
#                 state = "PH_Parse_Next_Line"

        for row in data:
            row.insert(0, mls_number)

        return data

mypath = "C:\\Users\\39118\\Desktop\\TRY"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector


rows = []
count = 0
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\TRY\\" + file)
#     print(data)
#     rows = rows+ list(data)
#     print(rows)

df = pd.DataFrame.from_records(rows)
print(df)
# df = pd.DataFrame({'a': headers, 'b': rows})
# df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\NeighborData.xlsx') as writer:
    df.to_excel(writer, 'sheet1',startrow=0, startcol=0, header=True, index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter

def extract_information(file):
    with open(file, mode="r") as ins:
        data=[]
        mls_number = ""
        i = 0
        LS = 0
        state=None
        for line in ins:
            i = i + 1            
            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue            
            if line == "SchoolsEducation :\n":
                print("File: {} list summary is found at line # {}".format(file, i))
                LS=1
                continue
                
            if LS == 1:
                entries = eval(line)  # Read the line as JSON array.
                for entry in entries:
                    print(entry)
                    data.append(entry)
  

                LS = 0
                
            if state == "LS_Parse_Next_Line":
                entries = eval(line)  # Read the line as JSON array.
#                 print(entries)
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]
#                         print(mls_number)
                state = None

        for row in data:
            print(row)
            row.insert(0, mls_number)
            
        return data


rows = []

mypath = "C:\\Users\\39118\\Desktop\\TRY"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector
print(list_files)
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\TRY\\" + file)
    print(type(data))
    rows=rows+data
#     print(rows)

df = pd.DataFrame(rows)
print(df)
# df = pd.DataFrame({'a': headers, 'b': rows})
# df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\NeighborData.xlsx') as writer:
    df.to_excel(writer, 'sheet1',startrow=0, startcol=0, header=True, index=False)
# Out:
# ['0.txt']
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 61
# ['College Degree - 2 year', '9.0%', '9.0%', '9.0%', '8.0%', 'The percentage of the area’s population over the age of 25 with an Associate Degree or other 2-year college degree.']
# ['College Degree - 4 year', '17.0%', '17.0%', '19.0%', '19.0%', 'The percentage of the area’s population over the age of 25 with a bachelor’s degree or other 4-year college degree.']
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 64
# ['00771912', 'Amityville Memorial High School', '10', '12', 717, 12, '11701', 1, 'Amityville Memorial High School', 'H ', '5']
# ['00774122', 'Lindenhurst Senior High School', '09', '12', 2000, 14, '11757', 1, 'Lindenhurst Senior High School', 'H ', '5']
# ['00737318', 'Massapequa High School', '10', '12', 1848, 13, '11758', 1, 'Massapequa High School', 'H ', '5']
# ['00772992', 'Walter G O Connell Copiague High School', '09', '12', 1610, 14, '11726', 1, 'Walter G O Connell Copiague High School', 'H ', '5']
# ['00737978', 'Plainedge Senior High School', '09', '12', 984, 13, '11758', 1, 'Plainedge Senior High School', 'H ', '5']
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 67
# ['00771900', 'Edmund W Miles Middle School', '07', '09', 650, 13, '11701', 1, 'Edmund W Miles Middle School', 'M ', '5']
# ['00774110', 'Lindenhurst Middle School', '06', '08', 1400, 12, '11757', 1, 'Lindenhurst Middle School', 'M ', '5']
# ['00773001', 'Copiague Middle School', '06', '08', 1100, 14, '11726', 1, 'Copiague Middle School', 'M ', '5']
# ['00737241', 'Berner Middle School', '07', '08', 1100, 12, '11758', 1, 'Berner Middle School', 'M ', '5']
# ['04875429', 'Massapequa High Ames Campus', '09', '09', 545, 10, '11758', 1, 'Massapequa High Ames Campus', 'M ', '5']
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 70
# ['00771948', 'Park Avenue School', '04', '06', 700, 10, '11701', 1, 'Park Avenue School', 'E ', '5']
# ['00771924', 'Northwest Elementary School', '01', '03', 650, 11, '11701', 1, 'Northwest Elementary School', 'E ', '5']
# ['00773049', 'Susan E Wiley School', 'KG', '05', 900, 16, '11726', 1, 'Susan E Wiley School', 'E ', '5']
# ['00737332', 'Unqua Elementary School', 'KG', '05', 670, 12, '11758', 1, 'Unqua Elementary School', 'E ', '5']
# ['00737291', 'Mckenna Elementary School', 'KG', '06', 621, 9, '11762', 1, 'Mckenna Elementary School', 'E ', '5']
# ['00737253', 'Birch Lane Elementary School', 'KG', '05', 618, 12, '11762', 1, 'Birch Lane Elementary School', 'E ', '5']
# ['00735449', 'Albany Avenue Elementary School', 'KG', '05', 565, 11, '11758', 1, 'Albany Avenue Elementary School', 'E ', '5']
# ['00774158', 'William Rall School', 'KG', '05', 560, 14, '11757', 1, 'William Rall School', 'E ', '5']
# ['00773025', 'Great Neck Road Elementary School', 'KG', '05', 535, 17, '11726', 1, 'Great Neck Road Elementary School', 'E ', '5']
# ['00774079', 'Daniel Street School', 'KG', '05', 526, 12, '11757', 1, 'Daniel Street School', 'E ', '5']
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 73
# 5700050096
# Northeast School
# PK
# KG
# 300
# 14
# 11701
# 1
# Northeast School
# U
# 5
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 76
# ['01464069', 'Bethesda Sda Elementary School', 'PK', '10', 43, 0, '11701', '1', 'Bethesda Sda Elementary School']
# ['00740585', 'St Rose Of Lima Elementary School', 'PK', '08', 484, 17, '11758', '1', 'St Rose Of Lima Elementary School']
# ['5700048488', 'St Martin Of Tours School', 'PK', '08', 372, 21, '11701', '1', 'St Martin Of Tours School']
# ['02932588', 'Kid Esteem Montessori School', 'PK', '08', 100, 10, '11757', '1', 'Kid Esteem Montessori School']
# ['02991572', 'Copiague Christian Academy', 'PK', '02', 44, 6, '11726', '1', 'Copiague Christian Academy']
# ['College Degree - 2 year', '9.0%', '9.0%', '9.0%', '8.0%', 'The percentage of the area’s population over the age of 25 with an Associate Degree or other 2-year college degree.']
# ['College Degree - 4 year', '17.0%', '17.0%', '19.0%', '19.0%', 'The percentage of the area’s population over the age of 25 with a bachelor’s degree or other 4-year college degree.']
# ['00771912', 'Amityville Memorial High School', '10', '12', 717, 12, '11701', 1, 'Amityville Memorial High School', 'H ', '5']
# ['00774122', 'Lindenhurst Senior High School', '09', '12', 2000, 14, '11757', 1, 'Lindenhurst Senior High School', 'H ', '5']
# ['00737318', 'Massapequa High School', '10', '12', 1848, 13, '11758', 1, 'Massapequa High School', 'H ', '5']
# ['00772992', 'Walter G O Connell Copiague High School', '09', '12', 1610, 14, '11726', 1, 'Walter G O Connell Copiague High School', 'H ', '5']
# ['00737978', 'Plainedge Senior High School', '09', '12', 984, 13, '11758', 1, 'Plainedge Senior High School', 'H ', '5']
# ['00771900', 'Edmund W Miles Middle School', '07', '09', 650, 13, '11701', 1, 'Edmund W Miles Middle School', 'M ', '5']
# ['00774110', 'Lindenhurst Middle School', '06', '08', 1400, 12, '11757', 1, 'Lindenhurst Middle School', 'M ', '5']
# ['00773001', 'Copiague Middle School', '06', '08', 1100, 14, '11726', 1, 'Copiague Middle School', 'M ', '5']
# ['00737241', 'Berner Middle School', '07', '08', 1100, 12, '11758', 1, 'Berner Middle School', 'M ', '5']
# ['04875429', 'Massapequa High Ames Campus', '09', '09', 545, 10, '11758', 1, 'Massapequa High Ames Campus', 'M ', '5']
# ['00771948', 'Park Avenue School', '04', '06', 700, 10, '11701', 1, 'Park Avenue School', 'E ', '5']
# ['00771924', 'Northwest Elementary School', '01', '03', 650, 11, '11701', 1, 'Northwest Elementary School', 'E ', '5']
# ['00773049', 'Susan E Wiley School', 'KG', '05', 900, 16, '11726', 1, 'Susan E Wiley School', 'E ', '5']
# ['00737332', 'Unqua Elementary School', 'KG', '05', 670, 12, '11758', 1, 'Unqua Elementary School', 'E ', '5']
# ['00737291', 'Mckenna Elementary School', 'KG', '06', 621, 9, '11762', 1, 'Mckenna Elementary School', 'E ', '5']
# ['00737253', 'Birch Lane Elementary School', 'KG', '05', 618, 12, '11762', 1, 'Birch Lane Elementary School', 'E ', '5']
# ['00735449', 'Albany Avenue Elementary School', 'KG', '05', 565, 11, '11758', 1, 'Albany Avenue Elementary School', 'E ', '5']
# ['00774158', 'William Rall School', 'KG', '05', 560, 14, '11757', 1, 'William Rall School', 'E ', '5']
# ['00773025', 'Great Neck Road Elementary School', 'KG', '05', 535, 17, '11726', 1, 'Great Neck Road Elementary School', 'E ', '5']
# ['00774079', 'Daniel Street School', 'KG', '05', 526, 12, '11757', 1, 'Daniel Street School', 'E ', '5']
# 5700050096
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-19604590477c> in <module>
#      52 print(list_files)
#      53 for file in list_files:
# ---> 54     data = extract_information("C:\\Users\\39118\\Desktop\\TRY\\" + file)
#      55     print(type(data))
#      56     rows=rows+data
#
# <ipython-input-90-19604590477c> in extract_information(file)
#      41         for row in data:
#      42             print(row)
# ---> 43             row.insert(0, mls_number)
#      44
#      45         return data
#
# AttributeError: 'str' object has no attribute 'insert'

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter

def extract_information(file):
    with open(file, mode="r") as ins:
        data=[]
        mls_number = ""
        i = 0
        LS = 0
        state=None
        for line in ins:
            i = i + 1            
            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue            
            if line == "SchoolsEducation :\n":
                print("File: {} list summary is found at line # {}".format(file, i))
                LS=1
                continue
                
            if LS == 1:
                entries = eval(line)  # Read the line as JSON array.
                for entry in entries:
#                     print(entry)
                    data.append(entry)
  

                LS = 0
                
            if state == "LS_Parse_Next_Line":
                entries = eval(line)  # Read the line as JSON array.
#                 print(entries)
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]
#                         print(mls_number)
                state = None

        for row in data:
            print(row)
            row.insert(0, mls_number)
            
        return data


rows = []

mypath = "C:\\Users\\39118\\Desktop\\TRY"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector
print(list_files)
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\TRY\\" + file)
    print(type(data))
    rows=rows+data
#     print(rows)

df = pd.DataFrame(rows)
# print(df)
# df = pd.DataFrame({'a': headers, 'b': rows})
# df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\NeighborData.xlsx') as writer:
    df.to_excel(writer, 'sheet1',startrow=0, startcol=0, header=True, index=False)
# Out:
# ['0.txt']
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 61
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 64
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 67
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 70
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 73
# File: C:\Users\39118\Desktop\TRY\0.txt list summary is found at line # 76
# ['College Degree - 2 year', '9.0%', '9.0%', '9.0%', '8.0%', 'The percentage of the area’s population over the age of 25 with an Associate Degree or other 2-year college degree.']
# ['College Degree - 4 year', '17.0%', '17.0%', '19.0%', '19.0%', 'The percentage of the area’s population over the age of 25 with a bachelor’s degree or other 4-year college degree.']
# ['00771912', 'Amityville Memorial High School', '10', '12', 717, 12, '11701', 1, 'Amityville Memorial High School', 'H ', '5']
# ['00774122', 'Lindenhurst Senior High School', '09', '12', 2000, 14, '11757', 1, 'Lindenhurst Senior High School', 'H ', '5']
# ['00737318', 'Massapequa High School', '10', '12', 1848, 13, '11758', 1, 'Massapequa High School', 'H ', '5']
# ['00772992', 'Walter G O Connell Copiague High School', '09', '12', 1610, 14, '11726', 1, 'Walter G O Connell Copiague High School', 'H ', '5']
# ['00737978', 'Plainedge Senior High School', '09', '12', 984, 13, '11758', 1, 'Plainedge Senior High School', 'H ', '5']
# ['00771900', 'Edmund W Miles Middle School', '07', '09', 650, 13, '11701', 1, 'Edmund W Miles Middle School', 'M ', '5']
# ['00774110', 'Lindenhurst Middle School', '06', '08', 1400, 12, '11757', 1, 'Lindenhurst Middle School', 'M ', '5']
# ['00773001', 'Copiague Middle School', '06', '08', 1100, 14, '11726', 1, 'Copiague Middle School', 'M ', '5']
# ['00737241', 'Berner Middle School', '07', '08', 1100, 12, '11758', 1, 'Berner Middle School', 'M ', '5']
# ['04875429', 'Massapequa High Ames Campus', '09', '09', 545, 10, '11758', 1, 'Massapequa High Ames Campus', 'M ', '5']
# ['00771948', 'Park Avenue School', '04', '06', 700, 10, '11701', 1, 'Park Avenue School', 'E ', '5']
# ['00771924', 'Northwest Elementary School', '01', '03', 650, 11, '11701', 1, 'Northwest Elementary School', 'E ', '5']
# ['00773049', 'Susan E Wiley School', 'KG', '05', 900, 16, '11726', 1, 'Susan E Wiley School', 'E ', '5']
# ['00737332', 'Unqua Elementary School', 'KG', '05', 670, 12, '11758', 1, 'Unqua Elementary School', 'E ', '5']
# ['00737291', 'Mckenna Elementary School', 'KG', '06', 621, 9, '11762', 1, 'Mckenna Elementary School', 'E ', '5']
# ['00737253', 'Birch Lane Elementary School', 'KG', '05', 618, 12, '11762', 1, 'Birch Lane Elementary School', 'E ', '5']
# ['00735449', 'Albany Avenue Elementary School', 'KG', '05', 565, 11, '11758', 1, 'Albany Avenue Elementary School', 'E ', '5']
# ['00774158', 'William Rall School', 'KG', '05', 560, 14, '11757', 1, 'William Rall School', 'E ', '5']
# ['00773025', 'Great Neck Road Elementary School', 'KG', '05', 535, 17, '11726', 1, 'Great Neck Road Elementary School', 'E ', '5']
# ['00774079', 'Daniel Street School', 'KG', '05', 526, 12, '11757', 1, 'Daniel Street School', 'E ', '5']
# 5700050096
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-6bbc423b32fd> in <module>
#      52 print(list_files)
#      53 for file in list_files:
# ---> 54     data = extract_information("C:\\Users\\39118\\Desktop\\TRY\\" + file)
#      55     print(type(data))
#      56     rows=rows+data
#
# <ipython-input-93-6bbc423b32fd> in extract_information(file)
#      41         for row in data:
#      42             print(row)
# ---> 43             row.insert(0, mls_number)
#      44
#      45         return data
#
# AttributeError: 'str' object has no attribute 'insert'

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter
import ast
def extract_information(file):
    with open(file,mode="r") as ins:
        data=[]
        mls_number = ""
        i = 0
        LS = 0
        state=None
        for line in ins:
            i = i + 1            
            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue            
            if line == "SchoolsEducation :\n":
                print("File: {} list summary is found at line # {}".format(file, i))
                LS=1
                continue
                
            if LS == 1:
                entries = eval(line)  # Read the line as JSON array.
                for entry in entries:
#                     print(entry)
                    data.append(entry)
  

                LS = 0
                
            if state == "LS_Parse_Next_Line":
                entries =eval(line)  # Read the line as JSON array.
                print(entries)
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]
#                         print(mls_number)
                state = None

        for row in data:
            if type(row)==list:
                print(row[1])
                
            else:
                pass
                

            
        return data


# rows = []

mypath = "C:\\Users\\39118\\Desktop\\TRY"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector
print(list_files)
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\TRY\\" + file)
    print(type(data))
df=pd.DataFrame({"data":data})
# print(df)



#     print(type(data))
# #     rows=rows+data
#     print(rows)

# df = pd.DataFrame(data)


# # # df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\HouseData.xlsx') as writer:
    df.to_excel(writer, 'Basic Information',startrow=0, startcol=0, header=True, index=False)

# %%
d1 = {'name': 'jason', 'age': 20, 'gender': 'male'}
d2 = dict({'name': 'jason', 'age': 20, 'gender': 'male'})
d3 = dict([('name', 'jason'), ('age', 20), ('gender', 'male')])
d4 = dict(name='jason', age=20, gender='male')
print(d1)
print(d2)
print(d3)
print(d4)
s1 = {1, 2, 3}
s2 = set([1, 2, 3])
print(s1)
print(s2)

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter
import ast
rows=[]
def extract_information(file):

    with open(file,mode="r") as ins:
        data=[]
        mls_number = ""
        i = 0
        LS = 0
        state=None
        for line in ins:
            i = i + 1            
            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue            
            if line == "SchoolsEducation :\n":
                print("File: {} list summary is found at line # {}".format(file, i))
                LS=1
                continue
                
            if LS == 1:
                entries = eval(line)  # Read the line as JSON array.
                for entry in entries:
                    data.append(entry)
               
  

                LS = 0
                
            if state == "LS_Parse_Next_Line":
                entries =eval(line)  # Read the line as JSON array.
#                 print(entries)
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]
#                         print(mls_number)
                state = None

        rows.append(mls_number)
        for row in data:
            if type(row)==list:
#                 print(row[1])
                rows.append(row[1])
               
                
            else:
                if type(row)==str:
                    if "School" in row:
                        print(row)
  
        print(rows)
            
        return rows




mypath = "C:\\Users\\39118\\Desktop\\Python Program\\LIINFO"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector
print(list_files)
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\Python Program\\LIINFO\\" + file)
    print(data)
df=pd.DataFrame({"School":data})

print(df)


#     print(type(data))
# #     rows=rows+data
#     print(rows)

# df = pd.DataFrame(data)


# # # df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\School Data.xlsx') as writer:
    df.to_excel(writer, 'School Information',startrow=0, startcol=0, header=True, index=False)

# %%
jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000
# Out:
#   File "<ipython-input-1-d280653ded63>", line 1
#     jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000
#                    ^
# SyntaxError: invalid syntax

# %%
# This code reads the text content and identifies the feature names and related values.
from os import listdir
from os.path import isfile, join
import pandas as pd
from pandas import ExcelWriter
import ast





def extract_information(file):
    with open(file, mode="r") as ins:
        data = []
        mls_number = ""

        state = None
        for line in ins:

            if line == "Listing Summary:\n":
                state = "LS_Parse_Next_Line"
                continue
            elif line == "Price History:\n":
                state = "PH_Skip_Next_Then_Parse_Next_Line"
                continue

            if state == "LS_Parse_Next_Line":
                entries =eval(line)  # Read the line as JSON array.
                for entry in entries:
                    if entry[0] == "MLS#":
                        mls_number = entry[1]

                state = None

            elif state == "PH_Parse_Next_Line":
                data = eval(line)
                state = None

            elif state == "PH_Skip_Next_Then_Parse_Next_Line":
                state = "PH_Parse_Next_Line"

        for row in data:
            row.insert(0, mls_number)

        return data


mypath = "C:\\Users\\39118\\Desktop\\Python Program\\LIINFO"  # Change this to your own directory
list_files = [f for f in listdir(mypath) if isfile(join(mypath, f))]  # Store all file names in a vector

headers = ['a', 'b', 'c', 'd', 'e']

rows = []
count = 0
for file in list_files:
    data = extract_information("C:\\Users\\39118\\Desktop\\Python Program\\LIINFO\\" + file)
    rows = rows + data

df = pd.DataFrame.from_records(rows, columns=headers)
# df = pd.DataFrame({'a': headers, 'b': rows})
# df = df.transpose()  # switches columns into rows
with pd.ExcelWriter('C:\\Users\\39118\Desktop\\PYTHON CODE\\PriceData.xlsx') as writer:
    df.to_excel(writer, 'sheet1',startrow=0, startcol=0, header=True, index=False)
